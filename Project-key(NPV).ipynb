# %% [markdown]
# <table align="center" width=70%>
#    <tr>
#       <td width="15%">
#          </td>
#           <td>
#             <div align="center">
#                <font color="#21618C" size=8px>
#                   <b> Mini Project - Python <br>Topic – Finance
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Bank)
#
# This dataset is related to direct marketing campaigns of a Portuguese banking institution.
# The marketing campaigns were based on phone calls.
# Often, more than one contact with the same client was required to assess
# if the product (bank term deposit) would be (or not) subscribed.
#
# #### Attribute information:
#
# **age :** Age of a person
#
# **job :** type of job
#
# **marital :** marital status (categorical: "married","divorced","single")
#
# **education :**  (categorical: "unknown","secondary","primary","tertiary")
#
# **default :**  has credit in default? (binary: "yes","no")
#
# **balance :**  average yearly balance, in euros
#
# **housing :**  has a housing loan? (binary: "yes","no")
#
# **loan :**  has personal loan? (binary: "yes","no")
#
# **contact :**  contact communication type (categorical: "unknown","telephone","cellular")
#
# **day :**  last contact day of the month (numeric)
#
# **month :**  last contact month of year
#
# **duration :**  last contact duration, in seconds
#
# **campaign :**  number of contacts performed during this campaign
#
# **pdays :**  number of days that passed by after the client was last contacted from a previous campaign
#
# **previous :**  number of contacts performed before this campaign and for this client (numeric)
#
# **poutcome :** : outcome of the previous marketing campaign
#
# **y :**  has the client subscribed to a term deposit? (binary: "yes","no")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Import data sets and Load data set

# %%
df=pd.read_csv('bank.csv')

df.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
df.shape
# Out:
# (4521, 17)

# %% [raw]
# This dataset is obtained from the survey conducted on 4521 people.

# %% [markdown]
# ##  2. Make the data proper to make use of data for analysis

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>A. Identify the Features data types before entering into the analysis</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(df.dtypes)
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b> B.  Convert the datatypes which are wrongly identified according to the business(domain). Kindly use the User Defined function and loop to convert the data types once.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [raw]
#  The datatypes in this dataset are all identified correctly.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b> C.Find and Remove missing if any. Use visualization to find the missing values or Use general method to find the missing values.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [raw]
# There are no null values in the given dataset.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>D. Find duplicates (if necessary) </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df[df.duplicated()== True].shape
# Out:
# (0, 17)

# %%
#This dataset has no duplicate values which means all 4521 samples are distinct.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                    <b>3. Find the average balance of the customer who belongs to the subscribed customer and non-subscribed customer and also use a related plot to show them in visualization. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby(['y'])['balance'].mean().round(2)
# Out:
# y
# no     1403.21
# yes    1571.96
# Name: balance, dtype: float64

# %%
sns.barplot(data=df,x=df['y'],y=df['balance'])
plt.xlabel('Subscription_Status')
plt.ylabel('Avg_Balance')
plt.title('Avg_Balance vs Subscription_Status')
plt.show()

# %%
# Average balance of subscribed customers is 1571.96 .
# Average balance of non-subscribed customers is 1403.21 .
# Hence Average balance of subscribed_customers is greater than that of non-subscribed_customers.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>4. Use a pie plot to find the distribution(frequency) of the education. Make sure to add labels and show the percentage of each education distribution. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
s=df['education'].value_counts()
plt.pie(s,labels=s.index,autopct='%.2f%%')
plt.show()

# %%
# 1.Majority of the people from survey has secondary education accounting to 51.01 percent.
# 2.There are only 4.14% of the people whose education status is unknown.
# 3.People with higher/tertiary eductaion level consisted of 29.86percent 
#   which is higher than people with only primary education.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>5. Create a function that should be able to create a new feature(Variable) called season using the month column </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
def season(x):
    if x in ['dec','jan','feb']:
        return 'winter'
    if x in ['mar','apr','may']:
        return 'spring'
    if x in ['jun','jul','aug']:
        return 'summer'
    if x in ['sep','oct','nov']:
        return 'autumn'

# %%
df['season']=df['month'].apply(season)
df['season'].value_counts()
# Out:
# summer    1870
# spring    1740
# autumn     521
# winter     390
# Name: season, dtype: int64

# %%
# The compaigning is most active in summer season as people contacted are 1870. 
# It is closely followed by spring season as people contacted are 1740.
# The compaigning is least active during winter as people contacted are 390.
# The people contacted for compaign during autumn are 521.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>6. Use the count plot with a variable that you created in the above question and also the Y variable to find the class distribution</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.countplot(data=df, x='season', hue='y')
plt.title('Class distribution by season and subscription status')
plt.show()

# %%
#The majority of people are conatcted in summer and spring while the minority are conatcted in winter and autumn.
# The proportion of clients who subscribed to a term deposit is higher in summer and lower in winter.
#  People who subscribed  are  less when compared to people who didn't sunbcribe in every season.
#The difference between no.of people subscribed and unsubscribed is highest for summer and least is winter.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>7. Use the Pdays feature and find does it cause any effect on the subscription of the term using the bar plot.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.barplot(data=df, y = 'pdays', x ='y')
plt.xlabel('Subscription_status')
plt.ylabel('PDays')
plt.title('Effect of pdays by subscription status')
plt.show()

# %%
pd.pivot_table(data=df,index='y', values='pdays', aggfunc=['mean'])
# Out:
#           mean
#          pdays
# y
# no   36.006000
# yes  68.639155

# %%
# The avg no.of days when people who subscribed are last contacted is around 68.
# The avg no.of days when people who didn't subscribe are last contacted is around 36.
# This data includes subscribers and non-subscribers who are not contacted
# The people who subscribed are more than non-subscribers.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>8. Replace the -1 as nan values for the P-days store.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['pdays'].replace(to_replace=[-1], value =[np.nan] )
# Out:
# 3705

# %%
# Out of 4521 people, 3705 people are not contacted in the previous compaign.
# only 816 are contacted in the previous compaign.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>9. Once you are done with question number 8, do the same analysis as question number 7.
# And observe the difference between question number 7 and question number 9</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.barplot(data=df, y = 'pdays', x ='y')
plt.xlabel('Subscription_status')
plt.ylabel('PDays')
plt.title('Effect of pdays on subscription status')
plt.show()

# %%
pd.pivot_table(data=df,index='y', values='pdays_new', aggfunc=['mean'])
# Out:
#            mean
#       pdays_new
# y
# no   233.215190
# yes  196.184783

# %%
# The avg no.of days when people who subscribed are last contacted is around 233.
# The avg no.of days when people who didn't subscribe are last contacted is around 196.
# This data does not include subscribers and non-subscribers who are not contacted.
# The people who subscribed are less than non-subscribers which is contrary to the previous outcome.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>10. Does the customer take the term subscription who has less than 0 balance?
# Hint: Use any kind of plot which would you the related information to this question.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.countplot(data= df[df['balance'] < 0], x = 'y')
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
df[df['balance'] < 0][['y']].value_counts()
# Out:
# y
# no     335
# yes     31
# dtype: int64

# %%
df[df['balance'] >= 0][['y']].value_counts()
# Out:
# y
# no     3665
# yes     490
# dtype: int64

# %%
# There are 366 people whose balance is less than 0 out of which only 31 people subscribed
# Out of 4155 people, only 490 people subscribed.
# Regardless of balance, people who subscribed are less than non-subscribed people.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>11. Use Pivot table to find the maximum balance for each type of job.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.pivot_table(data=df,index='job', values='balance', aggfunc=['max'])
# Out:
#                   max
#               balance
# job
# admin.          22171
# blue-collar     16353
# entrepreneur    42045
# housemaid       26965
# management      27359
# retired         71188
# self-employed   16430
# services        26394
# student         11555
# technician      27733
# unemployed       9019
# unknown          7337

# %%
sns.violinplot(data=df,x='balance',y='job')
plt.title('Job vs Balance ')
plt.show()

# %%
# The highest maximum balance belonged to the person who is retired which is 71188.
# The least maximum balance belonged to the person whose job is unknown which is 7337.
# The maximum balance is greater than 10000 for people with known jobs.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>12. Use the Age, balance, and Y column to plot the scatter plot and find what kind of relationship Age and balance had, and See the points which belong 0 and 1 class and how they are distributed.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(data =df, x = 'age', y = 'balance',hue='y')
plt.title('Relationship between age and balance by subscription status')
plt.show()

# %%
# From the graph we can infer that the balance in the accounts is regardless of age and subscription status.
# Most of the people has their balance less than 30,000.
# There are only two persons whose balance is greater than 30000.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>13.Use the violin plot and also the box plot to find the distribution of the balance for each class of the Y column. And try to tell why we have a Violin plot and Box plot both rather than one.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(data=df,y='y',x='balance')
plt.title('Distribution of the balance by subscription status ')
plt.ylabel('subscription status')
plt.show()

# %%
sns.violinplot(data=df,x='balance',y='y')
plt.title('Distribution of the balance by subscription status ')
plt.ylabel('subscription status')
plt.show()

# %%
# people with highest balances are non_subscribers.
# IQR is almost same for both subscribers and non-subscribers.
# There are more outliers in non-subscribers than subscribers.
# From both the plots we can infer that, this is right skewed data.

# %%
# 1.The box plot shows IQR,outliers and symmetry of data and is easy to read.
# 2.The violin plot is more informative than box plot as it also shows data distribution
#   along with stats summary but it is hard to read comparitive to box plot.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>14. Use a pie plot to know the Proportion(distribution) of the defaulters and non-defaulters.
# Note: Try to explore more parameters that are there in the pie-plot method.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=df['default'].value_counts(normalize=True)
plt.pie(x,autopct='%.2f%%',labels=('defaulters','non-defaulters'),explode=[0,0.2])
plt.title('Defaulters vs Non-defaulters')
plt.show()

# %%
# Most of the people accounting to 98.32% has credit in default.
# Only 1.68 % of people has credit not in default.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>15. Use Box plot and strip plot to know the distribution of the Pdays with respect to Y classes and differentiate both plots.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(data=df,x='y',y='pdays')
plt.xlabel('subscription status')
plt.title('Distribution of Pdays wrt subscription status')
plt.show()

# %%
sns.stripplot(data=df,x='y',y='pdays')
plt.xlabel('subscription status')
plt.title('Distribution of Pdays wrt subscription status')
plt.show()

# %%
# 1.The median pdays for class ‘yes’ is much higher than for class ‘no
# indicating that customers who subscribed to term deposit were contacted more recently than those who did not.
# 2.There are more outliers in class 'no' than class 'yes' which means some non-subscribers are contacted very long ago.

# %% [markdown]
# ## 3. Extra Questions with solutions

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b> 1. Check out if there is any relationship  between two numerical variables from the datset and analyse it if there any.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\TSRAn\AppData\Local\Temp\ipykernel_9780\2271070662.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
# as magnitude of correlation between them is not greater than 0.65

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>2. Use Pivot table to find Age Statistics for every job. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.pivot_table(data=df,index='job', values='age', aggfunc=['min','median','mean','max'])
# Out:
#               min median       mean max
#               age    age        age age
# job
# admin.         22   38.0  39.682008  66
# blue-collar    23   39.0  40.156448  75
# entrepreneur   23   41.0  42.011905  63
# housemaid      26   49.0  47.339286  80
# management     23   38.0  40.540764  80
# retired        24   59.0  61.869565  87
# self-employed  25   40.0  41.453552  62
# services       21   37.0  38.570743  60
# student        19   26.0  26.821429  42
# technician     22   38.0  39.470052  71
# unemployed     24   41.0  40.906250  60
# unknown        27   49.5  48.105263  71

# %%
# Minimum age for every job are in twenties except student whose minimum age is 19 .
# Maximum age for every job are  above 60 except student whose maximum age is 42 .
# The avg and median age for retired people is highest for retired people which is 61.87 and 59 respectively.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>3. Use a pie plot to find the distribution(frequency) of the Marital status of people.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
m=df['marital'].value_counts()
plt.pie(m,labels=m.index,autopct='%.2f%%')
plt.title('Distribution of marital status of people')
plt.show()

# %%
# Majority of the people are married which is 61.87%.
# Singles are accounted to 26.45%.
# Minority of people accounting to 11.68% are divorced/widowed.

# %% [markdown]
# <table align="left">
#     <tr>
#      <td width="6%">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="#21618C">
#                     <b>4. How many people have taken any type of loan ?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['loan'],df['housing'])
# Out:
# housing    no   yes
# loan
# no       1677  2153
# yes       285   406

# %%
sns.countplot(data=df,x='housing',hue='loan')
plt.xlabel('Housing loan')
plt.title('Class distribution of loans')
plt.show()

# %%
# 406 people has taken both personal and housing loans.
# 1677 people did not have any type of loan.
# 2153 people took only housing loan.
# 285 people took only personal loan.

# %% [markdown]
# 5.Write a program to count total default status per education status

# %%
pd.crosstab(index=df['default'],columns=df['education'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.crosstab(index=df['default'],columns=df['education'])
#
# NameError: name 'pd' is not defined
